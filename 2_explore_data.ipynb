# %% [markdown]
# ## Load and transform data

# %% [markdown]
# ### Load libraries

# %%
# conda install pandas
# conda install xlrd
# conda install openpyxl
# conda install numpy
# pip install sktime[all_extras]

# Libraries

import pandas as pd
import numpy as np
import sktime as sktime
import warnings
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sktime.utils.plotting import plot_series
from matplotlib.dates import DateFormatter
from warnings import simplefilter

# Filter warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load data

# %%
data = pd.read_excel("Output/data_ready.xlsx")
data
# Out:
#           Date  car  bike  bus
# 0   2004-01-01   93    14   24
# 1   2004-02-01   93    14   23
# 2   2004-03-01   95    17   23
# 3   2004-04-01   99    19   23
# 4   2004-05-01   97    20   23
# ..         ...  ...   ...  ...
# 199 2020-08-01   80    28   22
# 200 2020-09-01   76    25   22
# 201 2020-10-01   73    22   21
# 202 2020-11-01   65    21   20
# 203 2020-12-01   68    19   22
#
# [204 rows x 4 columns]

# %% [markdown]
# ### Explore

# %%
columns = data.columns

variables = columns[columns != 'Date']

for i in variables:
    
    # Variables
    
    var = i
    
    # Time series
    
    df = data[['Date',var]]
    ts = pd.Series(df[var].values, index = df['Date'])
    
    # Plot object 
    
    fig, ax = plot_series(ts)
    
    # Dates
    
    x_dates = df['Date'].dt.strftime('%Y-%m-%d').sort_values().unique()
    ax.xaxis.set_major_formatter(plt.FixedFormatter(x_dates))
    
    # Locators
    
    ax.set_xticklabels(x_dates)
    
    # Save
    
    ax.set(title = var, xlabel='Time', ylabel='Value')
    fig.savefig('Graphics/' + var + '.png')
